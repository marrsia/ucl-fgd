# %%
from utils.text_utils import *
from utils import data_analysis_utils as data

# %%
gpt2_surprisals = "../data/model_outputs/gpt2_wilcox2022_embed4_object_gap_stimuli_with_surprisals.csv"
grnn_surprisals = "../data/model_outputs/grnn_wilcox2022_embed4_object_gap_stimuli_with_surprisals.csv"
ngram_surprisals = "../data/model_outputs/ngram_wilcox2022_embed4_object_gap_stimuli_with_surprisals.csv"

# %%
configs = [
    {'sentence_group': 1, 'condition': '+wh_no_gap', 'levels_of_embedding': 3},
    {'sentence_group': 1, 'condition': '+wh_gap',    'levels_of_embedding': 3},
    {'sentence_group': 1, 'condition': '-wh_gap',    'levels_of_embedding': 3},
    {'sentence_group': 1, 'condition': '-wh_no_gap', 'levels_of_embedding': 3},
]

data.plot_surprisal_lines(gpt2_surprisals, configs)

# %% [markdown]
# ## GPT2

# %%
surprisal_df = pd.read_csv(gpt2_surprisals)

# wh-effect plot
data.plot_effect_bar_chart(
    surprisal_df,
    effect_fn=data.get_wh_effect,
    conditions=['gap', 'no_gap'],
    condition_labels=['+gap', '-gap'],
    title='Local Wh-Effect (GPT-2)',
    ylabel='Local Wh-Effect (surprisal difference)',
    surprisal_type="local",
    gap_type = "object"
)

# filler offloading plot
data.plot_effect_bar_chart(
    surprisal_df,
    effect_fn=data.get_filler_offloading_effect,
    conditions=['+wh', '-wh'],
    condition_labels=['+wh', '-wh'],
    title='Local Filler Offloading Effect (GPT-2)',
    ylabel='Filler Offloading (surprisal difference)',
    surprisal_type="local",
    gap_type = "object"
)
# Out:
# === STANDARD DEVIATIONS (Local Wh-Effect (GPT-2)) ===
#
#   +gap:
#     embedding 0: mean=-3.371, sd=2.335, n=54
#     embedding 1: mean=-3.733, sd=2.251, n=54
#     embedding 2: mean=-2.800, sd=1.803, n=54
#     embedding 3: mean=-1.729, sd=1.450, n=54
#     embedding 4: mean=-1.729, sd=1.450, n=54
#
#   -gap:
#     embedding 0: mean=2.754, sd=1.537, n=54
#     embedding 1: mean=2.412, sd=1.800, n=54
#     embedding 2: mean=1.589, sd=1.544, n=54
#     embedding 3: mean=0.996, sd=0.894, n=54
#     embedding 4: mean=0.996, sd=0.894, n=54
# === STANDARD DEVIATIONS (Local Filler Offloading Effect (GPT-2)) ===
#
#   +wh:
#     embedding 0: mean=-0.935, sd=3.433, n=54
#     embedding 1: mean=-0.100, sd=3.746, n=54
#     embedding 2: mean=1.521, sd=3.828, n=54
#     embedding 3: mean=2.428, sd=3.882, n=54
#     embedding 4: mean=2.428, sd=3.882, n=54
#
#   -wh:
#     embedding 0: mean=5.189, sd=3.861, n=54
#     embedding 1: mean=6.045, sd=3.894, n=54
#     embedding 2: mean=5.910, sd=3.762, n=54
#     embedding 3: mean=5.153, sd=4.197, n=54
#     embedding 4: mean=5.153, sd=4.197, n=54

# %%
surprisal_df = pd.read_csv(gpt2_surprisals)

# wh-effect plot
data.plot_effect_bar_chart(
    surprisal_df,
    effect_fn=data.get_wh_effect,
    conditions=['gap', 'no_gap'],
    condition_labels=['+gap', '-gap'],
    title='Local Wh-Effect (GPT-2)',
    ylabel='Mean-Local Wh-Effect (surprisal difference)',
    surprisal_type="local_mean",
    gap_type = "object"
)

# filler offloading plot
data.plot_effect_bar_chart(
    surprisal_df,
    effect_fn=data.get_filler_offloading_effect,
    conditions=['+wh', '-wh'],
    condition_labels=['+wh', '-wh'],
    title='Mean-Local Filler Offloading Effect (GPT-2)',
    ylabel='Filler Offloading (surprisal difference)',
    surprisal_type="local_mean",
    gap_type = "object"
)
# Out:
# === STANDARD DEVIATIONS (Local Wh-Effect (GPT-2)) ===
#
#   +gap:
#     embedding 0: mean=-1.597, sd=0.993, n=54
#     embedding 1: mean=-1.665, sd=0.803, n=54
#     embedding 2: mean=-1.182, sd=0.647, n=54
#     embedding 3: mean=-0.729, sd=0.608, n=54
#     embedding 4: mean=-0.729, sd=0.608, n=54
#
#   -gap:
#     embedding 0: mean=1.876, sd=1.390, n=54
#     embedding 1: mean=1.612, sd=1.642, n=54
#     embedding 2: mean=0.997, sd=1.370, n=54
#     embedding 3: mean=0.596, sd=0.554, n=54
#     embedding 4: mean=0.596, sd=0.554, n=54
# === STANDARD DEVIATIONS (Mean-Local Filler Offloading Effect (GPT-2)) ===
#
#   +wh:
#     embedding 0: mean=-3.073, sd=2.566, n=54
#     embedding 1: mean=-2.365, sd=2.745, n=54
#     embedding 2: mean=-1.510, sd=2.828, n=54
#     embedding 3: mean=-0.879, sd=2.807, n=54
#     embedding 4: mean=-0.879, sd=2.807, n=54
#
#   -wh:
#     embedding 0: mean=0.401, sd=2.570, n=54
#     embedding 1: mean=0.913, sd=2.770, n=54
#     embedding 2: mean=0.669, sd=2.816, n=54
#     embedding 3: mean=0.446, sd=2.771, n=54
#     embedding 4: mean=0.446, sd=2.771, n=54

# %%
surprisal_df = pd.read_csv(gpt2_surprisals)

# wh-effect plot
data.plot_effect_bar_chart(
    surprisal_df,
    effect_fn=data.get_wh_effect,
    conditions=['gap', 'no_gap'],
    condition_labels=['+gap', '-gap'],
    title='Semi-local Wh-Effect (GPT-2)',
    ylabel='Wh-Effect (surprisal difference)',
    surprisal_type="semi_local",
    gap_type = "object"
)

# filler offloading plot
data.plot_effect_bar_chart(
    surprisal_df,
    effect_fn=data.get_filler_offloading_effect,
    conditions=['+wh', '-wh'],
    condition_labels=['+wh', '-wh'],
    title='Semi-Local Filler Offloading Effect (GPT-2)',
    ylabel='Filler Offloading (surprisal difference)',
    surprisal_type="semi_local",
    gap_type = "object"
)
# Out:
# === STANDARD DEVIATIONS (Semi-local Wh-Effect (GPT-2)) ===
#
#   +gap:
#     embedding 0: mean=-1.597, sd=0.993, n=54
#     embedding 1: mean=-1.665, sd=0.803, n=54
#     embedding 2: mean=-1.182, sd=0.647, n=54
#     embedding 3: mean=-0.729, sd=0.608, n=54
#     embedding 4: mean=-0.729, sd=0.608, n=54
#
#   -gap:
#     embedding 0: mean=0.898, sd=0.667, n=54
#     embedding 1: mean=0.692, sd=0.577, n=54
#     embedding 2: mean=0.397, sd=0.446, n=54
#     embedding 3: mean=0.252, sd=0.248, n=54
#     embedding 4: mean=0.252, sd=0.248, n=54
# === STANDARD DEVIATIONS (Semi-Local Filler Offloading Effect (GPT-2)) ===
#
#   +wh:
#     embedding 0: mean=-1.262, sd=1.385, n=54
#     embedding 1: mean=-0.813, sd=1.372, n=54
#     embedding 2: mean=-0.187, sd=1.455, n=54
#     embedding 3: mean=0.172, sd=1.552, n=54
#     embedding 4: mean=0.172, sd=1.552, n=54
#
#   -wh:
#     embedding 0: mean=1.233, sd=1.535, n=54
#     embedding 1: mean=1.545, sd=1.556, n=54
#     embedding 2: mean=1.391, sd=1.593, n=54
#     embedding 3: mean=1.153, sd=1.650, n=54
#     embedding 4: mean=1.153, sd=1.650, n=54

# %% [markdown]
# ## GRNN

# %%
surprisal_df = pd.read_csv(grnn_surprisals)

# wh-effect plot
data.plot_effect_bar_chart(
    surprisal_df,
    effect_fn=data.get_wh_effect,
    conditions=['gap', 'no_gap'],
    condition_labels=['+gap', '-gap'],
    title='Local Wh-Effect (GRNN)',
    ylabel='Local Wh-Effect (surprisal difference)',
    surprisal_type="local",
    gap_type = "object"
)

# filler offloading plot
data.plot_effect_bar_chart(
    surprisal_df,
    effect_fn=data.get_filler_offloading_effect,
    conditions=['+wh', '-wh'],
    condition_labels=['+wh', '-wh'],
    title='Local Filler Offloading Effect (GRNN)',
    ylabel='Filler Offloading (surprisal difference)',
    surprisal_type="local",
    gap_type = "object"
)
# Out:
# === STANDARD DEVIATIONS (Local Wh-Effect (GRNN)) ===
#
#   +gap:
#     embedding 0: mean=-2.633, sd=1.938, n=54
#     embedding 1: mean=-1.721, sd=1.886, n=54
#     embedding 2: mean=-1.461, sd=1.881, n=54
#     embedding 3: mean=-0.903, sd=1.622, n=54
#     embedding 4: mean=-0.903, sd=1.622, n=54
#
#   -gap:
#     embedding 0: mean=1.964, sd=1.141, n=54
#     embedding 1: mean=1.567, sd=1.377, n=54
#     embedding 2: mean=1.315, sd=1.392, n=54
#     embedding 3: mean=0.971, sd=1.319, n=54
#     embedding 4: mean=0.971, sd=1.319, n=54
# === STANDARD DEVIATIONS (Local Filler Offloading Effect (GRNN)) ===
#
#   +wh:
#     embedding 0: mean=2.487, sd=5.940, n=54
#     embedding 1: mean=3.636, sd=6.492, n=54
#     embedding 2: mean=3.909, sd=6.673, n=54
#     embedding 3: mean=4.749, sd=6.636, n=54
#     embedding 4: mean=4.749, sd=6.636, n=54
#
#   -wh:
#     embedding 0: mean=7.084, sd=5.547, n=54
#     embedding 1: mean=6.923, sd=5.469, n=54
#     embedding 2: mean=6.685, sd=5.678, n=54
#     embedding 3: mean=6.623, sd=5.784, n=54
#     embedding 4: mean=6.623, sd=5.784, n=54

# %%
surprisal_df = pd.read_csv(grnn_surprisals)

# wh-effect plot
data.plot_effect_bar_chart(
    surprisal_df,
    effect_fn=data.get_wh_effect,
    conditions=['gap', 'no_gap'],
    condition_labels=['+gap', '-gap'],
    title='Local Wh-Effect (GRNN)',
    ylabel='Local Wh-Effect (surprisal difference)',
    surprisal_type="local_mean",
    gap_type = "object"
)

# filler offloading plot
data.plot_effect_bar_chart(
    surprisal_df,
    effect_fn=data.get_filler_offloading_effect,
    conditions=['+wh', '-wh'],
    condition_labels=['+wh', '-wh'],
    title='Local Filler Offloading Effect (GRNN)',
    ylabel='Filler Offloading (surprisal difference)',
    surprisal_type="local_mean",
    gap_type = "object"
)
# Out:
# === STANDARD DEVIATIONS (Local Wh-Effect (GRNN)) ===
#
#   +gap:
#     embedding 0: mean=-1.121, sd=0.927, n=54
#     embedding 1: mean=-0.747, sd=0.709, n=54
#     embedding 2: mean=-0.675, sd=0.740, n=54
#     embedding 3: mean=-0.379, sd=0.555, n=54
#     embedding 4: mean=-0.379, sd=0.555, n=54
#
#   -gap:
#     embedding 0: mean=0.972, sd=0.726, n=54
#     embedding 1: mean=0.759, sd=0.802, n=54
#     embedding 2: mean=0.662, sd=0.798, n=54
#     embedding 3: mean=0.511, sd=0.761, n=54
#     embedding 4: mean=0.511, sd=0.761, n=54
# === STANDARD DEVIATIONS (Local Filler Offloading Effect (GRNN)) ===
#
#   +wh:
#     embedding 0: mean=-0.975, sd=3.319, n=54
#     embedding 1: mean=-0.416, sd=3.744, n=54
#     embedding 2: mean=-0.311, sd=3.936, n=54
#     embedding 3: mean=0.077, sd=3.927, n=54
#     embedding 4: mean=0.077, sd=3.927, n=54
#
#   -wh:
#     embedding 0: mean=1.118, sd=3.706, n=54
#     embedding 1: mean=1.090, sd=3.658, n=54
#     embedding 2: mean=1.026, sd=3.724, n=54
#     embedding 3: mean=0.967, sd=3.700, n=54
#     embedding 4: mean=0.967, sd=3.700, n=54

# %%
surprisal_df = pd.read_csv(grnn_surprisals)


# wh-effect plot
data.plot_effect_bar_chart(
    surprisal_df,
    effect_fn=data.get_wh_effect,
    conditions=['gap', 'no_gap'],
    condition_labels=['+gap', '-gap'],
    title='Semi-local Wh-Effect (GRNN)',
    ylabel='Wh-Effect (surprisal difference)',
    surprisal_type="semi_local",
    gap_type = "object"
)

# filler offloading plot
data.plot_effect_bar_chart(
    surprisal_df,
    effect_fn=data.get_filler_offloading_effect,
    conditions=['+wh', '-wh'],
    condition_labels=['+wh', '-wh'],
    title='Semi-Local Filler Offloading Effect (GRNN)',
    ylabel='Filler Offloading (surprisal difference)',
    surprisal_type="semi_local",
    gap_type = "object"
)
# Out:
# === STANDARD DEVIATIONS (Semi-local Wh-Effect (GRNN)) ===
#
#   +gap:
#     embedding 0: mean=-1.121, sd=0.927, n=54
#     embedding 1: mean=-0.747, sd=0.709, n=54
#     embedding 2: mean=-0.675, sd=0.740, n=54
#     embedding 3: mean=-0.379, sd=0.555, n=54
#     embedding 4: mean=-0.379, sd=0.555, n=54
#
#   -gap:
#     embedding 0: mean=0.417, sd=0.392, n=54
#     embedding 1: mean=0.338, sd=0.393, n=54
#     embedding 2: mean=0.283, sd=0.394, n=54
#     embedding 3: mean=0.221, sd=0.371, n=54
#     embedding 4: mean=0.221, sd=0.371, n=54
# === STANDARD DEVIATIONS (Semi-Local Filler Offloading Effect (GRNN)) ===
#
#   +wh:
#     embedding 0: mean=-0.148, sd=1.762, n=54
#     embedding 1: mean=0.275, sd=2.098, n=54
#     embedding 2: mean=0.383, sd=2.297, n=54
#     embedding 3: mean=0.673, sd=2.290, n=54
#     embedding 4: mean=0.673, sd=2.290, n=54
#
#   -wh:
#     embedding 0: mean=1.389, sd=2.093, n=54
#     embedding 1: mean=1.361, sd=2.081, n=54
#     embedding 2: mean=1.342, sd=2.169, n=54
#     embedding 3: mean=1.272, sd=2.128, n=54
#     embedding 4: mean=1.272, sd=2.128, n=54

# %% [markdown]
# ## ngram

# %%
surprisal_df = pd.read_csv(ngram_surprisals)

# wh-effect plot
data.plot_effect_bar_chart(
    surprisal_df,
    effect_fn=data.get_wh_effect,
    conditions=['gap', 'no_gap'],
    condition_labels=['+gap', '-gap'],
    title='Local Wh-Effect (NGRAM)',
    ylabel='Local Wh-Effect (surprisal difference)',
    surprisal_type="local",
    gap_type = "object"
)

# filler offloading plot
data.plot_effect_bar_chart(
    surprisal_df,
    effect_fn=data.get_filler_offloading_effect,
    conditions=['+wh', '-wh'],
    condition_labels=['+wh', '-wh'],
    title='Local Filler Offloading Effect (NGRAM)',
    ylabel='Filler Offloading (surprisal difference)',
    surprisal_type="local",
    gap_type = "object"
)
# Out:
# /home/marrsia/.local/lib/python3.8/site-packages/scipy/stats/_distn_infrastructure.py:2128: RuntimeWarning: invalid value encountered in multiply
#   lower_bound = _a * scale + loc
# /home/marrsia/.local/lib/python3.8/site-packages/scipy/stats/_distn_infrastructure.py:2129: RuntimeWarning: invalid value encountered in multiply
#   upper_bound = _b * scale + loc
# /home/marrsia/.local/lib/python3.8/site-packages/scipy/stats/_distn_infrastructure.py:2128: RuntimeWarning: invalid value encountered in multiply
#   lower_bound = _a * scale + loc
# /home/marrsia/.local/lib/python3.8/site-packages/scipy/stats/_distn_infrastructure.py:2129: RuntimeWarning: invalid value encountered in multiply
#   upper_bound = _b * scale + loc
# === STANDARD DEVIATIONS (Local Wh-Effect (NGRAM)) ===
#
#   +gap:
#     embedding 0: mean=0.000, sd=0.000, n=54
#     embedding 1: mean=0.000, sd=0.000, n=54
#     embedding 2: mean=0.000, sd=0.000, n=54
#     embedding 3: mean=0.000, sd=0.000, n=54
#     embedding 4: mean=0.000, sd=0.000, n=54
#
#   -gap:
#     embedding 0: mean=0.000, sd=0.000, n=54
#     embedding 1: mean=0.000, sd=0.000, n=54
#     embedding 2: mean=0.000, sd=0.000, n=54
#     embedding 3: mean=0.000, sd=0.000, n=54
#     embedding 4: mean=0.000, sd=0.000, n=54
# === STANDARD DEVIATIONS (Local Filler Offloading Effect (NGRAM)) ===
#
#   +wh:
#     embedding 0: mean=4.125, sd=4.633, n=54
#     embedding 1: mean=4.125, sd=4.633, n=54
#     embedding 2: mean=4.125, sd=4.633, n=54
#     embedding 3: mean=4.125, sd=4.633, n=54
#     embedding 4: mean=4.125, sd=4.633, n=54
#
#   -wh:
#     embedding 0: mean=4.125, sd=4.633, n=54
#     embedding 1: mean=4.125, sd=4.633, n=54
#     embedding 2: mean=4.125, sd=4.633, n=54
#     embedding 3: mean=4.125, sd=4.633, n=54
#     embedding 4: mean=4.125, sd=4.633, n=54

# %%
surprisal_df = pd.read_csv(ngram_surprisals)

# wh-effect plot
data.plot_effect_bar_chart(
    surprisal_df,
    effect_fn=data.get_wh_effect,
    conditions=['gap', 'no_gap'],
    condition_labels=['+gap', '-gap'],
    title='Local Wh-Effect (NGRAM)',
    ylabel='Local Wh-Effect (surprisal difference)',
    surprisal_type="local_mean",
    gap_type = "object"
)

# filler offloading plot
data.plot_effect_bar_chart(
    surprisal_df,
    effect_fn=data.get_filler_offloading_effect,
    conditions=['+wh', '-wh'],
    condition_labels=['+wh', '-wh'],
    title='Local Filler Offloading Effect (NGRAM)',
    ylabel='Filler Offloading (surprisal difference)',
    surprisal_type="local_mean",
    gap_type = "object"
)
# Out:
# /home/marrsia/.local/lib/python3.8/site-packages/scipy/stats/_distn_infrastructure.py:2128: RuntimeWarning: invalid value encountered in multiply
#   lower_bound = _a * scale + loc
# /home/marrsia/.local/lib/python3.8/site-packages/scipy/stats/_distn_infrastructure.py:2129: RuntimeWarning: invalid value encountered in multiply
#   upper_bound = _b * scale + loc
# === STANDARD DEVIATIONS (Local Wh-Effect (NGRAM)) ===
#
#   +gap:
#     embedding 0: mean=-0.017, sd=0.125, n=54
#     embedding 1: mean=-0.017, sd=0.125, n=54
#     embedding 2: mean=-0.017, sd=0.125, n=54
#     embedding 3: mean=-0.017, sd=0.125, n=54
#     embedding 4: mean=-0.017, sd=0.125, n=54
#
#   -gap:
#     embedding 0: mean=0.000, sd=0.000, n=54
#     embedding 1: mean=0.000, sd=0.000, n=54
#     embedding 2: mean=0.000, sd=0.000, n=54
#     embedding 3: mean=0.000, sd=0.000, n=54
#     embedding 4: mean=0.000, sd=0.000, n=54
# === STANDARD DEVIATIONS (Local Filler Offloading Effect (NGRAM)) ===
#
#   +wh:
#     embedding 0: mean=-0.172, sd=2.786, n=54
#     embedding 1: mean=-0.172, sd=2.786, n=54
#     embedding 2: mean=-0.172, sd=2.786, n=54
#     embedding 3: mean=-0.172, sd=2.786, n=54
#     embedding 4: mean=-0.172, sd=2.786, n=54
#
#   -wh:
#     embedding 0: mean=-0.155, sd=2.774, n=54
#     embedding 1: mean=-0.155, sd=2.774, n=54
#     embedding 2: mean=-0.155, sd=2.774, n=54
#     embedding 3: mean=-0.155, sd=2.774, n=54
#     embedding 4: mean=-0.155, sd=2.774, n=54

# %%
surprisal_df = pd.read_csv(ngram_surprisals)

# wh-effect plot
data.plot_effect_bar_chart(
    surprisal_df,
    effect_fn=data.get_wh_effect,
    conditions=['gap', 'no_gap'],
    condition_labels=['+gap', '-gap'],
    title='Semi-local Wh-Effect (NGRAM)',
    ylabel='Local Wh-Effect (surprisal difference)',
    surprisal_type="semi_local",
    gap_type = "object"
)

# filler offloading plot
data.plot_effect_bar_chart(
    surprisal_df,
    effect_fn=data.get_filler_offloading_effect,
    conditions=['+wh', '-wh'],
    condition_labels=['+wh', '-wh'],
    title='Semi-Local Filler Offloading Effect (NGRAM)',
    ylabel='Filler Offloading (surprisal difference)',
    surprisal_type="semi_local",
    gap_type = "object"
)
# Out:
# === STANDARD DEVIATIONS (Semi-local Wh-Effect (NGRAM)) ===
#
#   +gap:
#     embedding 0: mean=-0.017, sd=0.125, n=54
#     embedding 1: mean=-0.017, sd=0.125, n=54
#     embedding 2: mean=-0.017, sd=0.125, n=54
#     embedding 3: mean=-0.017, sd=0.125, n=54
#     embedding 4: mean=-0.017, sd=0.125, n=54
#
#   -gap:
#     embedding 0: mean=-0.011, sd=0.079, n=54
#     embedding 1: mean=-0.011, sd=0.079, n=54
#     embedding 2: mean=-0.011, sd=0.079, n=54
#     embedding 3: mean=-0.011, sd=0.079, n=54
#     embedding 4: mean=-0.011, sd=0.079, n=54
# === STANDARD DEVIATIONS (Semi-Local Filler Offloading Effect (NGRAM)) ===
#
#   +wh:
#     embedding 0: mean=0.118, sd=1.516, n=54
#     embedding 1: mean=0.118, sd=1.516, n=54
#     embedding 2: mean=0.118, sd=1.516, n=54
#     embedding 3: mean=0.118, sd=1.516, n=54
#     embedding 4: mean=0.118, sd=1.516, n=54
#
#   -wh:
#     embedding 0: mean=0.125, sd=1.517, n=54
#     embedding 1: mean=0.125, sd=1.517, n=54
#     embedding 2: mean=0.125, sd=1.517, n=54
#     embedding 3: mean=0.125, sd=1.517, n=54
#     embedding 4: mean=0.125, sd=1.517, n=54

# %% [markdown]
# ## Multi-model

# %%
gpt2_df = pd.read_csv(gpt2_surprisals)
grnn_df = pd.read_csv(grnn_surprisals)
ngram_df = pd.read_csv(ngram_surprisals)

model_dfs = {
    "GPT-2": gpt2_df,
    "GRNN":  grnn_df,
    "ngram": ngram_df,
}

data.plot_effect_bar_chart_multi_model(
    model_dfs     = model_dfs,
    effect_fn     = data.get_wh_effect,
    conditions    = ["gap", "no_gap"],
    title         = "Wh-effect by model and embedding level -- local (first token)",
    ylabel        = "Surprisal difference (bits)",
    surprisal_type= "local",
    gap_type      = "object",
    condition_labels = ["gap", "no_gap"]
)
# Out:
# /home/marrsia/.local/lib/python3.8/site-packages/scipy/stats/_distn_infrastructure.py:2128: RuntimeWarning: invalid value encountered in multiply
#   lower_bound = _a * scale + loc
# /home/marrsia/.local/lib/python3.8/site-packages/scipy/stats/_distn_infrastructure.py:2129: RuntimeWarning: invalid value encountered in multiply
#   upper_bound = _b * scale + loc
# /home/marrsia/.local/lib/python3.8/site-packages/scipy/stats/_distn_infrastructure.py:2128: RuntimeWarning: invalid value encountered in multiply
#   lower_bound = _a * scale + loc
# /home/marrsia/.local/lib/python3.8/site-packages/scipy/stats/_distn_infrastructure.py:2129: RuntimeWarning: invalid value encountered in multiply
#   upper_bound = _b * scale + loc
# === STANDARD DEVIATIONS (Wh-effect by model and embedding level -- local (first token)) ===
#
#   [GPT-2]
#   gap:
#     embedding 0: mean=-3.371, sd=2.335, n=54
#     embedding 1: mean=-3.733, sd=2.251, n=54
#     embedding 2: mean=-2.800, sd=1.803, n=54
#     embedding 3: mean=-1.729, sd=1.450, n=54
#     embedding 4: mean=-1.729, sd=1.450, n=54
#   no_gap:
#     embedding 0: mean=2.754, sd=1.537, n=54
#     embedding 1: mean=2.412, sd=1.800, n=54
#     embedding 2: mean=1.589, sd=1.544, n=54
#     embedding 3: mean=0.996, sd=0.894, n=54
#     embedding 4: mean=0.996, sd=0.894, n=54
#
#   [GRNN]
#   gap:
#     embedding 0: mean=-2.633, sd=1.938, n=54
#     embedding 1: mean=-1.721, sd=1.886, n=54
#     embedding 2: mean=-1.461, sd=1.881, n=54
#     embedding 3: mean=-0.903, sd=1.622, n=54
#     embedding 4: mean=-0.903, sd=1.622, n=54
#   no_gap:
#     embedding 0: mean=1.964, sd=1.141, n=54
#     embedding 1: mean=1.567, sd=1.377, n=54
#     embedding 2: mean=1.315, sd=1.392, n=54
#     embedding 3: mean=0.971, sd=1.319, n=54
#     embedding 4: mean=0.971, sd=1.319, n=54
#
#   [ngram]
#   gap:
#     embedding 0: mean=0.000, sd=0.000, n=54
#     embedding 1: mean=0.000, sd=0.000, n=54
#     embedding 2: mean=0.000, sd=0.000, n=54
#     embedding 3: mean=0.000, sd=0.000, n=54
#     embedding 4: mean=0.000, sd=0.000, n=54
#   no_gap:
#     embedding 0: mean=0.000, sd=0.000, n=54
#     embedding 1: mean=0.000, sd=0.000, n=54
#     embedding 2: mean=0.000, sd=0.000, n=54
#     embedding 3: mean=0.000, sd=0.000, n=54
#     embedding 4: mean=0.000, sd=0.000, n=54

# %%
gpt2_df = pd.read_csv(gpt2_surprisals)
grnn_df = pd.read_csv(grnn_surprisals)
ngram_df = pd.read_csv(ngram_surprisals)

model_dfs = {
    "GPT-2": gpt2_df,
    "GRNN":  grnn_df,
    "ngram": ngram_df,
}

data.plot_effect_bar_chart_multi_model(
    model_dfs     = model_dfs,
    effect_fn     = data.get_wh_effect,
    conditions    = ["gap", "no_gap"],
    title         = "Wh-effect by model and embedding level -- local (mean)",
    ylabel        = "Surprisal difference (bits)",
    surprisal_type= "local_mean",
    gap_type      = "object",
    condition_labels = ["gap", "no_gap"]
)
# Out:
# /home/marrsia/.local/lib/python3.8/site-packages/scipy/stats/_distn_infrastructure.py:2128: RuntimeWarning: invalid value encountered in multiply
#   lower_bound = _a * scale + loc
# /home/marrsia/.local/lib/python3.8/site-packages/scipy/stats/_distn_infrastructure.py:2129: RuntimeWarning: invalid value encountered in multiply
#   upper_bound = _b * scale + loc
# === STANDARD DEVIATIONS (Wh-effect by model and embedding level -- local (mean)) ===
#
#   [GPT-2]
#   gap:
#     embedding 0: mean=-1.597, sd=0.993, n=54
#     embedding 1: mean=-1.665, sd=0.803, n=54
#     embedding 2: mean=-1.182, sd=0.647, n=54
#     embedding 3: mean=-0.729, sd=0.608, n=54
#     embedding 4: mean=-0.729, sd=0.608, n=54
#   no_gap:
#     embedding 0: mean=1.876, sd=1.390, n=54
#     embedding 1: mean=1.612, sd=1.642, n=54
#     embedding 2: mean=0.997, sd=1.370, n=54
#     embedding 3: mean=0.596, sd=0.554, n=54
#     embedding 4: mean=0.596, sd=0.554, n=54
#
#   [GRNN]
#   gap:
#     embedding 0: mean=-1.121, sd=0.927, n=54
#     embedding 1: mean=-0.747, sd=0.709, n=54
#     embedding 2: mean=-0.675, sd=0.740, n=54
#     embedding 3: mean=-0.379, sd=0.555, n=54
#     embedding 4: mean=-0.379, sd=0.555, n=54
#   no_gap:
#     embedding 0: mean=0.972, sd=0.726, n=54
#     embedding 1: mean=0.759, sd=0.802, n=54
#     embedding 2: mean=0.662, sd=0.798, n=54
#     embedding 3: mean=0.511, sd=0.761, n=54
#     embedding 4: mean=0.511, sd=0.761, n=54
#
#   [ngram]
#   gap:
#     embedding 0: mean=-0.017, sd=0.125, n=54
#     embedding 1: mean=-0.017, sd=0.125, n=54
#     embedding 2: mean=-0.017, sd=0.125, n=54
#     embedding 3: mean=-0.017, sd=0.125, n=54
#     embedding 4: mean=-0.017, sd=0.125, n=54
#   no_gap:
#     embedding 0: mean=0.000, sd=0.000, n=54
#     embedding 1: mean=0.000, sd=0.000, n=54
#     embedding 2: mean=0.000, sd=0.000, n=54
#     embedding 3: mean=0.000, sd=0.000, n=54
#     embedding 4: mean=0.000, sd=0.000, n=54

# %%
data.plot_effect_bar_chart_multi_model(
    model_dfs     = model_dfs,
    effect_fn     = data.get_filler_offloading_effect,
    conditions    = ["+wh", "-wh"],
    title         = "Local Filler-offloading by model and embedding level -- local (first token)",
    ylabel        = "Surprisal difference (bits)",
    surprisal_type= "local",
    gap_type      = "object",
    condition_labels = ["+wh", "-wh"]
)
# Out:
# === STANDARD DEVIATIONS (Local Filler-offloading by model and embedding level -- local (first token)) ===
#
#   [GPT-2]
#   +wh:
#     embedding 0: mean=-0.935, sd=3.433, n=54
#     embedding 1: mean=-0.100, sd=3.746, n=54
#     embedding 2: mean=1.521, sd=3.828, n=54
#     embedding 3: mean=2.428, sd=3.882, n=54
#     embedding 4: mean=2.428, sd=3.882, n=54
#   -wh:
#     embedding 0: mean=5.189, sd=3.861, n=54
#     embedding 1: mean=6.045, sd=3.894, n=54
#     embedding 2: mean=5.910, sd=3.762, n=54
#     embedding 3: mean=5.153, sd=4.197, n=54
#     embedding 4: mean=5.153, sd=4.197, n=54
#
#   [GRNN]
#   +wh:
#     embedding 0: mean=2.487, sd=5.940, n=54
#     embedding 1: mean=3.636, sd=6.492, n=54
#     embedding 2: mean=3.909, sd=6.673, n=54
#     embedding 3: mean=4.749, sd=6.636, n=54
#     embedding 4: mean=4.749, sd=6.636, n=54
#   -wh:
#     embedding 0: mean=7.084, sd=5.547, n=54
#     embedding 1: mean=6.923, sd=5.469, n=54
#     embedding 2: mean=6.685, sd=5.678, n=54
#     embedding 3: mean=6.623, sd=5.784, n=54
#     embedding 4: mean=6.623, sd=5.784, n=54
#
#   [ngram]
#   +wh:
#     embedding 0: mean=4.125, sd=4.633, n=54
#     embedding 1: mean=4.125, sd=4.633, n=54
#     embedding 2: mean=4.125, sd=4.633, n=54
#     embedding 3: mean=4.125, sd=4.633, n=54
#     embedding 4: mean=4.125, sd=4.633, n=54
#   -wh:
#     embedding 0: mean=4.125, sd=4.633, n=54
#     embedding 1: mean=4.125, sd=4.633, n=54
#     embedding 2: mean=4.125, sd=4.633, n=54
#     embedding 3: mean=4.125, sd=4.633, n=54
#     embedding 4: mean=4.125, sd=4.633, n=54

# %%
data.plot_effect_bar_chart_multi_model(
    model_dfs     = model_dfs,
    effect_fn     = data.get_filler_offloading_effect,
    conditions    = ["+wh", "-wh"],
    title         = "Local Filler-offloading by model and embedding level -- local (mean)",
    ylabel        = "Surprisal difference (bits)",
    surprisal_type= "local_mean",
    gap_type      = "object",
    condition_labels = ["+wh", "-wh"]
)
# Out:
# === STANDARD DEVIATIONS (Local Filler-offloading by model and embedding level -- local (mean)) ===
#
#   [GPT-2]
#   +wh:
#     embedding 0: mean=-3.073, sd=2.566, n=54
#     embedding 1: mean=-2.365, sd=2.745, n=54
#     embedding 2: mean=-1.510, sd=2.828, n=54
#     embedding 3: mean=-0.879, sd=2.807, n=54
#     embedding 4: mean=-0.879, sd=2.807, n=54
#   -wh:
#     embedding 0: mean=0.401, sd=2.570, n=54
#     embedding 1: mean=0.913, sd=2.770, n=54
#     embedding 2: mean=0.669, sd=2.816, n=54
#     embedding 3: mean=0.446, sd=2.771, n=54
#     embedding 4: mean=0.446, sd=2.771, n=54
#
#   [GRNN]
#   +wh:
#     embedding 0: mean=-0.975, sd=3.319, n=54
#     embedding 1: mean=-0.416, sd=3.744, n=54
#     embedding 2: mean=-0.311, sd=3.936, n=54
#     embedding 3: mean=0.077, sd=3.927, n=54
#     embedding 4: mean=0.077, sd=3.927, n=54
#   -wh:
#     embedding 0: mean=1.118, sd=3.706, n=54
#     embedding 1: mean=1.090, sd=3.658, n=54
#     embedding 2: mean=1.026, sd=3.724, n=54
#     embedding 3: mean=0.967, sd=3.700, n=54
#     embedding 4: mean=0.967, sd=3.700, n=54
#
#   [ngram]
#   +wh:
#     embedding 0: mean=-0.172, sd=2.786, n=54
#     embedding 1: mean=-0.172, sd=2.786, n=54
#     embedding 2: mean=-0.172, sd=2.786, n=54
#     embedding 3: mean=-0.172, sd=2.786, n=54
#     embedding 4: mean=-0.172, sd=2.786, n=54
#   -wh:
#     embedding 0: mean=-0.155, sd=2.774, n=54
#     embedding 1: mean=-0.155, sd=2.774, n=54
#     embedding 2: mean=-0.155, sd=2.774, n=54
#     embedding 3: mean=-0.155, sd=2.774, n=54
#     embedding 4: mean=-0.155, sd=2.774, n=54

# %%
data.plot_effect_bar_chart_multi_model(
    model_dfs     = model_dfs,
    effect_fn     = data.get_filler_offloading_effect,
    conditions    = ["+wh", "-wh"],
    title         = "Semi Local Filler-offloading by model and embedding level",
    ylabel        = "Surprisal difference (bits)",
    surprisal_type= "semi_local",
    gap_type      = "object",
    condition_labels = ["+wh", "-wh"]
)
# Out:
# === STANDARD DEVIATIONS (Semi Local Filler-offloading by model and embedding level) ===
#
#   [GPT-2]
#   +wh:
#     embedding 0: mean=-1.262, sd=1.385, n=54
#     embedding 1: mean=-0.813, sd=1.372, n=54
#     embedding 2: mean=-0.187, sd=1.455, n=54
#     embedding 3: mean=0.172, sd=1.552, n=54
#     embedding 4: mean=0.172, sd=1.552, n=54
#   -wh:
#     embedding 0: mean=1.233, sd=1.535, n=54
#     embedding 1: mean=1.545, sd=1.556, n=54
#     embedding 2: mean=1.391, sd=1.593, n=54
#     embedding 3: mean=1.153, sd=1.650, n=54
#     embedding 4: mean=1.153, sd=1.650, n=54
#
#   [GRNN]
#   +wh:
#     embedding 0: mean=-0.148, sd=1.762, n=54
#     embedding 1: mean=0.275, sd=2.098, n=54
#     embedding 2: mean=0.383, sd=2.297, n=54
#     embedding 3: mean=0.673, sd=2.290, n=54
#     embedding 4: mean=0.673, sd=2.290, n=54
#   -wh:
#     embedding 0: mean=1.389, sd=2.093, n=54
#     embedding 1: mean=1.361, sd=2.081, n=54
#     embedding 2: mean=1.342, sd=2.169, n=54
#     embedding 3: mean=1.272, sd=2.128, n=54
#     embedding 4: mean=1.272, sd=2.128, n=54
#
#   [ngram]
#   +wh:
#     embedding 0: mean=0.118, sd=1.516, n=54
#     embedding 1: mean=0.118, sd=1.516, n=54
#     embedding 2: mean=0.118, sd=1.516, n=54
#     embedding 3: mean=0.118, sd=1.516, n=54
#     embedding 4: mean=0.118, sd=1.516, n=54
#   -wh:
#     embedding 0: mean=0.125, sd=1.517, n=54
#     embedding 1: mean=0.125, sd=1.517, n=54
#     embedding 2: mean=0.125, sd=1.517, n=54
#     embedding 3: mean=0.125, sd=1.517, n=54
#     embedding 4: mean=0.125, sd=1.517, n=54
