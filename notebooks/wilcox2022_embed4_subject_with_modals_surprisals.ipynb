# %%
from utils.text_utils import *
from utils import data_analysis_utils as data

# %%
gpt2_surprisals = "../data/model_outputs/gpt2_wilcox2022_embed4_subject_gap_with_modals_stimuli_with_surprisals.csv"
grnn_surprisals = "../data/model_outputs/grnn_wilcox2022_embed4_subject_gap_with_modals_stimuli_with_surprisals.csv"
ngram_surprisals = "../data/model_outputs/ngram_wilcox2022_embed4_subject_gap_with_modals_stimuli_with_surprisals.csv"

# %%
configs = [
    {'sentence_group': 1, 'condition': '+wh_no_gap', 'levels_of_embedding': 3},
    {'sentence_group': 1, 'condition': '+wh_gap',    'levels_of_embedding': 3},
    {'sentence_group': 1, 'condition': '-wh_gap',    'levels_of_embedding': 3},
    {'sentence_group': 1, 'condition': '-wh_no_gap', 'levels_of_embedding': 3},
]

data.plot_surprisal_lines(gpt2_surprisals, configs)

# %% [markdown]
# ## GPT2

# %%
surprisal_df = pd.read_csv(gpt2_surprisals)

# wh-effect plot
data.plot_effect_bar_chart(
    surprisal_df,
    effect_fn=data.get_wh_effect,
    conditions=['gap', 'no_gap'],
    condition_labels=['+gap', '-gap'],
    title='Local Wh-Effect (GPT-2)',
    ylabel='Local Wh-Effect (surprisal difference)',
    surprisal_type="local",
    gap_type = "subject"
)

# filler offloading plot
data.plot_effect_bar_chart(
    surprisal_df,
    effect_fn=data.get_filler_offloading_effect,
    conditions=['+wh', '-wh'],
    condition_labels=['+wh', '-wh'],
    title='Local Filler Offloading Effect (GPT-2)',
    ylabel='Filler Offloading (surprisal difference)',
    surprisal_type="local",
    gap_type = "subject"
)
# Out:
# === STANDARD DEVIATIONS (Local Wh-Effect (GPT-2)) ===
#
#   +gap:
#     embedding 0: mean=-4.795, sd=2.506, n=54
#     embedding 1: mean=-5.381, sd=1.894, n=54
#     embedding 2: mean=-4.341, sd=1.962, n=54
#     embedding 3: mean=-2.584, sd=1.809, n=54
#     embedding 4: mean=-2.584, sd=1.809, n=54
#
#   -gap:
#     embedding 0: mean=0.911, sd=0.847, n=54
#     embedding 1: mean=2.045, sd=1.378, n=54
#     embedding 2: mean=2.250, sd=1.254, n=54
#     embedding 3: mean=2.048, sd=1.304, n=54
#     embedding 4: mean=2.048, sd=1.304, n=54
# === STANDARD DEVIATIONS (Local Filler Offloading Effect (GPT-2)) ===
#
#   +wh:
#     embedding 0: mean=3.693, sd=1.556, n=54
#     embedding 1: mean=3.181, sd=2.166, n=54
#     embedding 2: mean=4.638, sd=2.485, n=54
#     embedding 3: mean=5.950, sd=2.459, n=54
#     embedding 4: mean=5.950, sd=2.459, n=54
#
#   -wh:
#     embedding 0: mean=9.400, sd=2.447, n=54
#     embedding 1: mean=10.607, sd=1.880, n=54
#     embedding 2: mean=11.228, sd=1.954, n=54
#     embedding 3: mean=10.583, sd=2.413, n=54
#     embedding 4: mean=10.583, sd=2.413, n=54

# %%
surprisal_df = pd.read_csv(gpt2_surprisals)

# wh-effect plot
data.plot_effect_bar_chart(
    surprisal_df,
    effect_fn=data.get_wh_effect,
    conditions=['gap', 'no_gap'],
    condition_labels=['+gap', '-gap'],
    title='Semi-local Wh-Effect (GPT-2)',
    ylabel='Wh-Effect (surprisal difference)',
    surprisal_type="semi_local",
    gap_type = "subject"
)

# filler offloading plot
data.plot_effect_bar_chart(
    surprisal_df,
    effect_fn=data.get_filler_offloading_effect,
    conditions=['+wh', '-wh'],
    condition_labels=['+wh', '-wh'],
    title='Semi-Local Filler Offloading Effect (GPT-2)',
    ylabel='Filler Offloading (surprisal difference)',
    surprisal_type="semi_local",
    gap_type = "subject"
)
# Out:
# === STANDARD DEVIATIONS (Semi-local Wh-Effect (GPT-2)) ===
#
#   +gap:
#     embedding 0: mean=-1.181, sd=0.497, n=54
#     embedding 1: mean=-0.776, sd=0.443, n=54
#     embedding 2: mean=-0.589, sd=0.371, n=54
#     embedding 3: mean=-0.342, sd=0.323, n=54
#     embedding 4: mean=-0.342, sd=0.323, n=54
#
#   -gap:
#     embedding 0: mean=0.537, sd=0.403, n=54
#     embedding 1: mean=0.630, sd=0.336, n=54
#     embedding 2: mean=0.402, sd=0.316, n=54
#     embedding 3: mean=0.280, sd=0.280, n=54
#     embedding 4: mean=0.280, sd=0.280, n=54
# === STANDARD DEVIATIONS (Semi-Local Filler Offloading Effect (GPT-2)) ===
#
#   +wh:
#     embedding 0: mean=-0.107, sd=0.708, n=54
#     embedding 1: mean=-0.041, sd=0.786, n=54
#     embedding 2: mean=0.287, sd=0.794, n=54
#     embedding 3: mean=0.405, sd=0.759, n=54
#     embedding 4: mean=0.405, sd=0.759, n=54
#
#   -wh:
#     embedding 0: mean=1.611, sd=0.786, n=54
#     embedding 1: mean=1.365, sd=0.823, n=54
#     embedding 2: mean=1.277, sd=0.819, n=54
#     embedding 3: mean=1.026, sd=0.871, n=54
#     embedding 4: mean=1.026, sd=0.871, n=54

# %% [markdown]
# ## GRNN

# %%
surprisal_df = pd.read_csv(grnn_surprisals)

# wh-effect plot
data.plot_effect_bar_chart(
    surprisal_df,
    effect_fn=data.get_wh_effect,
    conditions=['gap', 'no_gap'],
    condition_labels=['+gap', '-gap'],
    title='Local Wh-Effect (GRNN)',
    ylabel='Local Wh-Effect (surprisal difference)',
    surprisal_type="local",
    gap_type = "subject"
)

# filler offloading plot
data.plot_effect_bar_chart(
    surprisal_df,
    effect_fn=data.get_filler_offloading_effect,
    conditions=['+wh', '-wh'],
    condition_labels=['+wh', '-wh'],
    title='Local Filler Offloading Effect (GRNN)',
    ylabel='Filler Offloading (surprisal difference)',
    surprisal_type="local",
    gap_type = "subject"
)
# Out:
# === STANDARD DEVIATIONS (Local Wh-Effect (GRNN)) ===
#
#   +gap:
#     embedding 0: mean=-6.590, sd=0.952, n=54
#     embedding 1: mean=-4.802, sd=1.728, n=54
#     embedding 2: mean=-3.293, sd=1.889, n=54
#     embedding 3: mean=-2.088, sd=1.876, n=54
#     embedding 4: mean=-2.088, sd=1.876, n=54
#
#   -gap:
#     embedding 0: mean=3.230, sd=1.184, n=54
#     embedding 1: mean=1.590, sd=0.587, n=54
#     embedding 2: mean=1.367, sd=0.864, n=54
#     embedding 3: mean=0.891, sd=0.959, n=54
#     embedding 4: mean=0.891, sd=0.959, n=54
# === STANDARD DEVIATIONS (Local Filler Offloading Effect (GRNN)) ===
#
#   +wh:
#     embedding 0: mean=1.951, sd=1.969, n=54
#     embedding 1: mean=3.655, sd=2.128, n=54
#     embedding 2: mean=4.540, sd=2.685, n=54
#     embedding 3: mean=7.085, sd=3.192, n=54
#     embedding 4: mean=7.085, sd=3.192, n=54
#
#   -wh:
#     embedding 0: mean=11.771, sd=2.074, n=54
#     embedding 1: mean=10.048, sd=2.925, n=54
#     embedding 2: mean=9.200, sd=2.720, n=54
#     embedding 3: mean=10.064, sd=2.439, n=54
#     embedding 4: mean=10.064, sd=2.439, n=54

# %%
surprisal_df = pd.read_csv(grnn_surprisals)


# wh-effect plot
data.plot_effect_bar_chart(
    surprisal_df,
    effect_fn=data.get_wh_effect,
    conditions=['gap', 'no_gap'],
    condition_labels=['+gap', '-gap'],
    title='Semi-local Wh-Effect (GRNN)',
    ylabel='Wh-Effect (surprisal difference)',
    surprisal_type="semi_local",
    gap_type = "subject"
)

# filler offloading plot
data.plot_effect_bar_chart(
    surprisal_df,
    effect_fn=data.get_filler_offloading_effect,
    conditions=['+wh', '-wh'],
    condition_labels=['+wh', '-wh'],
    title='Semi-Local Filler Offloading Effect (GRNN)',
    ylabel='Filler Offloading (surprisal difference)',
    surprisal_type="semi_local",
    gap_type = "subject"
)
# Out:
# === STANDARD DEVIATIONS (Semi-local Wh-Effect (GRNN)) ===
#
#   +gap:
#     embedding 0: mean=-1.302, sd=0.270, n=54
#     embedding 1: mean=-0.567, sd=0.334, n=54
#     embedding 2: mean=-0.346, sd=0.255, n=54
#     embedding 3: mean=-0.239, sd=0.274, n=54
#     embedding 4: mean=-0.239, sd=0.274, n=54
#
#   -gap:
#     embedding 0: mean=0.457, sd=0.302, n=54
#     embedding 1: mean=0.343, sd=0.238, n=54
#     embedding 2: mean=0.268, sd=0.245, n=54
#     embedding 3: mean=0.140, sd=0.192, n=54
#     embedding 4: mean=0.140, sd=0.192, n=54
# === STANDARD DEVIATIONS (Semi-Local Filler Offloading Effect (GRNN)) ===
#
#   +wh:
#     embedding 0: mean=-0.357, sd=0.826, n=54
#     embedding 1: mean=0.145, sd=0.823, n=54
#     embedding 2: mean=0.241, sd=0.839, n=54
#     embedding 3: mean=0.497, sd=0.899, n=54
#     embedding 4: mean=0.497, sd=0.899, n=54
#
#   -wh:
#     embedding 0: mean=1.402, sd=0.784, n=54
#     embedding 1: mean=1.054, sd=0.873, n=54
#     embedding 2: mean=0.855, sd=0.803, n=54
#     embedding 3: mean=0.876, sd=0.871, n=54
#     embedding 4: mean=0.876, sd=0.871, n=54

# %% [markdown]
# ## ngram

# %%
surprisal_df = pd.read_csv(ngram_surprisals)

# wh-effect plot
data.plot_effect_bar_chart(
    surprisal_df,
    effect_fn=data.get_wh_effect,
    conditions=['gap', 'no_gap'],
    condition_labels=['+gap', '-gap'],
    title='Local Wh-Effect (NGRAM)',
    ylabel='Local Wh-Effect (surprisal difference)',
    surprisal_type="local",
    gap_type = "subject"
)

# filler offloading plot
data.plot_effect_bar_chart(
    surprisal_df,
    effect_fn=data.get_filler_offloading_effect,
    conditions=['+wh', '-wh'],
    condition_labels=['+wh', '-wh'],
    title='Local Filler Offloading Effect (NGRAM)',
    ylabel='Filler Offloading (surprisal difference)',
    surprisal_type="local",
    gap_type = "subject"
)
# Out:
# /home/marrsia/.local/lib/python3.8/site-packages/scipy/stats/_distn_infrastructure.py:2128: RuntimeWarning: invalid value encountered in multiply
#   lower_bound = _a * scale + loc
# /home/marrsia/.local/lib/python3.8/site-packages/scipy/stats/_distn_infrastructure.py:2129: RuntimeWarning: invalid value encountered in multiply
#   upper_bound = _b * scale + loc
# /home/marrsia/.local/lib/python3.8/site-packages/scipy/stats/_distn_infrastructure.py:2128: RuntimeWarning: invalid value encountered in multiply
#   lower_bound = _a * scale + loc
# /home/marrsia/.local/lib/python3.8/site-packages/scipy/stats/_distn_infrastructure.py:2129: RuntimeWarning: invalid value encountered in multiply
#   upper_bound = _b * scale + loc
# === STANDARD DEVIATIONS (Local Wh-Effect (NGRAM)) ===
#
#   +gap:
#     embedding 0: mean=-1.234, sd=0.772, n=54
#     embedding 1: mean=0.000, sd=0.000, n=54
#     embedding 2: mean=0.000, sd=0.000, n=54
#     embedding 3: mean=0.000, sd=0.000, n=54
#     embedding 4: mean=0.000, sd=0.000, n=54
#
#   -gap:
#     embedding 0: mean=3.015, sd=2.517, n=54
#     embedding 1: mean=0.000, sd=0.000, n=54
#     embedding 2: mean=0.000, sd=0.000, n=54
#     embedding 3: mean=0.000, sd=0.000, n=54
#     embedding 4: mean=0.000, sd=0.000, n=54
# === STANDARD DEVIATIONS (Local Filler Offloading Effect (NGRAM)) ===
#
#   +wh:
#     embedding 0: mean=1.728, sd=2.904, n=54
#     embedding 1: mean=7.101, sd=2.271, n=54
#     embedding 2: mean=7.419, sd=2.024, n=54
#     embedding 3: mean=6.815, sd=2.383, n=54
#     embedding 4: mean=6.815, sd=2.383, n=54
#
#   -wh:
#     embedding 0: mean=5.976, sd=1.449, n=54
#     embedding 1: mean=7.101, sd=2.271, n=54
#     embedding 2: mean=7.419, sd=2.024, n=54
#     embedding 3: mean=6.815, sd=2.383, n=54
#     embedding 4: mean=6.815, sd=2.383, n=54

# %%
surprisal_df = pd.read_csv(ngram_surprisals)

# wh-effect plot
data.plot_effect_bar_chart(
    surprisal_df,
    effect_fn=data.get_wh_effect,
    conditions=['gap', 'no_gap'],
    condition_labels=['+gap', '-gap'],
    title='Semi-local Wh-Effect (NGRAM)',
    ylabel='Local Wh-Effect (surprisal difference)',
    surprisal_type="semi_local",
    gap_type = "subject"
)

# filler offloading plot
data.plot_effect_bar_chart(
    surprisal_df,
    effect_fn=data.get_filler_offloading_effect,
    conditions=['+wh', '-wh'],
    condition_labels=['+wh', '-wh'],
    title='Semi-Local Filler Offloading Effect (NGRAM)',
    ylabel='Filler Offloading (surprisal difference)',
    surprisal_type="semi_local",
    gap_type = "subject"
)
# Out:
# /home/marrsia/.local/lib/python3.8/site-packages/scipy/stats/_distn_infrastructure.py:2128: RuntimeWarning: invalid value encountered in multiply
#   lower_bound = _a * scale + loc
# /home/marrsia/.local/lib/python3.8/site-packages/scipy/stats/_distn_infrastructure.py:2129: RuntimeWarning: invalid value encountered in multiply
#   upper_bound = _b * scale + loc
# /home/marrsia/.local/lib/python3.8/site-packages/scipy/stats/_distn_infrastructure.py:2128: RuntimeWarning: invalid value encountered in multiply
#   lower_bound = _a * scale + loc
# /home/marrsia/.local/lib/python3.8/site-packages/scipy/stats/_distn_infrastructure.py:2129: RuntimeWarning: invalid value encountered in multiply
#   upper_bound = _b * scale + loc
# === STANDARD DEVIATIONS (Semi-local Wh-Effect (NGRAM)) ===
#
#   +gap:
#     embedding 0: mean=-0.234, sd=0.167, n=54
#     embedding 1: mean=0.000, sd=0.000, n=54
#     embedding 2: mean=0.000, sd=0.000, n=54
#     embedding 3: mean=0.000, sd=0.000, n=54
#     embedding 4: mean=0.000, sd=0.000, n=54
#
#   -gap:
#     embedding 0: mean=0.328, sd=0.318, n=54
#     embedding 1: mean=0.000, sd=0.000, n=54
#     embedding 2: mean=0.000, sd=0.000, n=54
#     embedding 3: mean=0.000, sd=0.000, n=54
#     embedding 4: mean=0.000, sd=0.000, n=54
# === STANDARD DEVIATIONS (Semi-Local Filler Offloading Effect (NGRAM)) ===
#
#   +wh:
#     embedding 0: mean=-0.480, sd=0.708, n=54
#     embedding 1: mean=0.143, sd=0.608, n=54
#     embedding 2: mean=0.173, sd=0.589, n=54
#     embedding 3: mean=0.095, sd=0.573, n=54
#     embedding 4: mean=0.095, sd=0.573, n=54
#
#   -wh:
#     embedding 0: mean=0.082, sd=0.646, n=54
#     embedding 1: mean=0.143, sd=0.608, n=54
#     embedding 2: mean=0.173, sd=0.589, n=54
#     embedding 3: mean=0.095, sd=0.573, n=54
#     embedding 4: mean=0.095, sd=0.573, n=54

# %% [markdown]
# ## Multi-model

# %%
gpt2_df = pd.read_csv(gpt2_surprisals)
grnn_df = pd.read_csv(grnn_surprisals)
ngram_df = pd.read_csv(ngram_surprisals)

model_dfs = {
    "GPT-2": gpt2_df,
    "GRNN":  grnn_df,
    "ngram": ngram_df,
}

data.plot_effect_bar_chart_multi_model(
    model_dfs     = model_dfs,
    effect_fn     = data.get_wh_effect,
    conditions    = ["gap", "no_gap"],
    title         = "Wh-effect by model and embedding level",
    ylabel        = "Surprisal difference (bits)",
    surprisal_type= "local",
    gap_type      = "subject",
    condition_labels = ["gap", "no_gap"]
)
# Out:
# /home/marrsia/.local/lib/python3.8/site-packages/scipy/stats/_distn_infrastructure.py:2128: RuntimeWarning: invalid value encountered in multiply
#   lower_bound = _a * scale + loc
# /home/marrsia/.local/lib/python3.8/site-packages/scipy/stats/_distn_infrastructure.py:2129: RuntimeWarning: invalid value encountered in multiply
#   upper_bound = _b * scale + loc
# /home/marrsia/.local/lib/python3.8/site-packages/scipy/stats/_distn_infrastructure.py:2128: RuntimeWarning: invalid value encountered in multiply
#   lower_bound = _a * scale + loc
# /home/marrsia/.local/lib/python3.8/site-packages/scipy/stats/_distn_infrastructure.py:2129: RuntimeWarning: invalid value encountered in multiply
#   upper_bound = _b * scale + loc
# === STANDARD DEVIATIONS (Wh-effect by model and embedding level) ===
#
#   [GPT-2]
#   gap:
#     embedding 0: mean=-4.795, sd=2.506, n=54
#     embedding 1: mean=-5.381, sd=1.894, n=54
#     embedding 2: mean=-4.341, sd=1.962, n=54
#     embedding 3: mean=-2.584, sd=1.809, n=54
#     embedding 4: mean=-2.584, sd=1.809, n=54
#   no_gap:
#     embedding 0: mean=0.911, sd=0.847, n=54
#     embedding 1: mean=2.045, sd=1.378, n=54
#     embedding 2: mean=2.250, sd=1.254, n=54
#     embedding 3: mean=2.048, sd=1.304, n=54
#     embedding 4: mean=2.048, sd=1.304, n=54
#
#   [GRNN]
#   gap:
#     embedding 0: mean=-6.590, sd=0.952, n=54
#     embedding 1: mean=-4.802, sd=1.728, n=54
#     embedding 2: mean=-3.293, sd=1.889, n=54
#     embedding 3: mean=-2.088, sd=1.876, n=54
#     embedding 4: mean=-2.088, sd=1.876, n=54
#   no_gap:
#     embedding 0: mean=3.230, sd=1.184, n=54
#     embedding 1: mean=1.590, sd=0.587, n=54
#     embedding 2: mean=1.367, sd=0.864, n=54
#     embedding 3: mean=0.891, sd=0.959, n=54
#     embedding 4: mean=0.891, sd=0.959, n=54
#
#   [ngram]
#   gap:
#     embedding 0: mean=-1.234, sd=0.772, n=54
#     embedding 1: mean=0.000, sd=0.000, n=54
#     embedding 2: mean=0.000, sd=0.000, n=54
#     embedding 3: mean=0.000, sd=0.000, n=54
#     embedding 4: mean=0.000, sd=0.000, n=54
#   no_gap:
#     embedding 0: mean=3.015, sd=2.517, n=54
#     embedding 1: mean=0.000, sd=0.000, n=54
#     embedding 2: mean=0.000, sd=0.000, n=54
#     embedding 3: mean=0.000, sd=0.000, n=54
#     embedding 4: mean=0.000, sd=0.000, n=54

# %%
data.plot_effect_bar_chart_multi_model(
    model_dfs     = model_dfs,
    effect_fn     = data.get_filler_offloading_effect,
    conditions    = ["+wh", "-wh"],
    title         = "Semi Local Filler-offloading by model and embedding level",
    ylabel        = "Surprisal difference (bits)",
    surprisal_type= "semi_local",
    gap_type      = "object",
    condition_labels = ["+wh", "-wh"]
)
# Out:
# === STANDARD DEVIATIONS (Semi Local Filler-offloading by model and embedding level) ===
#
#   [GPT-2]
#   +wh:
#     embedding 0: mean=-0.107, sd=0.708, n=54
#     embedding 1: mean=-0.041, sd=0.786, n=54
#     embedding 2: mean=0.287, sd=0.794, n=54
#     embedding 3: mean=0.405, sd=0.759, n=54
#     embedding 4: mean=0.405, sd=0.759, n=54
#   -wh:
#     embedding 0: mean=1.611, sd=0.786, n=54
#     embedding 1: mean=1.365, sd=0.823, n=54
#     embedding 2: mean=1.277, sd=0.819, n=54
#     embedding 3: mean=1.026, sd=0.871, n=54
#     embedding 4: mean=1.026, sd=0.871, n=54
#
#   [GRNN]
#   +wh:
#     embedding 0: mean=-0.357, sd=0.826, n=54
#     embedding 1: mean=0.145, sd=0.823, n=54
#     embedding 2: mean=0.241, sd=0.839, n=54
#     embedding 3: mean=0.497, sd=0.899, n=54
#     embedding 4: mean=0.497, sd=0.899, n=54
#   -wh:
#     embedding 0: mean=1.402, sd=0.784, n=54
#     embedding 1: mean=1.054, sd=0.873, n=54
#     embedding 2: mean=0.855, sd=0.803, n=54
#     embedding 3: mean=0.876, sd=0.871, n=54
#     embedding 4: mean=0.876, sd=0.871, n=54
#
#   [ngram]
#   +wh:
#     embedding 0: mean=-0.480, sd=0.708, n=54
#     embedding 1: mean=0.143, sd=0.608, n=54
#     embedding 2: mean=0.173, sd=0.589, n=54
#     embedding 3: mean=0.095, sd=0.573, n=54
#     embedding 4: mean=0.095, sd=0.573, n=54
#   -wh:
#     embedding 0: mean=0.082, sd=0.646, n=54
#     embedding 1: mean=0.143, sd=0.608, n=54
#     embedding 2: mean=0.173, sd=0.589, n=54
#     embedding 3: mean=0.095, sd=0.573, n=54
#     embedding 4: mean=0.095, sd=0.573, n=54

# %%
data.plot_effect_bar_chart_multi_model(
    model_dfs     = model_dfs,
    effect_fn     = data.get_filler_offloading_effect,
    conditions    = ["+wh", "-wh"],
    title         = "Local Filler-offloading by model and embedding level",
    ylabel        = "Surprisal difference (bits)",
    surprisal_type= "local",
    gap_type      = "object",
    condition_labels = ["+wh", "-wh"]
)
# Out:
# === STANDARD DEVIATIONS (Local Filler-offloading by model and embedding level) ===
#
#   [GPT-2]
#   +wh:
#     embedding 0: mean=-0.085, sd=3.599, n=54
#     embedding 1: mean=0.303, sd=3.677, n=54
#     embedding 2: mean=1.342, sd=3.907, n=54
#     embedding 3: mean=1.886, sd=3.938, n=54
#     embedding 4: mean=1.886, sd=3.938, n=54
#   -wh:
#     embedding 0: mean=2.863, sd=4.084, n=54
#     embedding 1: mean=2.638, sd=3.980, n=54
#     embedding 2: mean=2.672, sd=4.128, n=54
#     embedding 3: mean=2.719, sd=4.202, n=54
#     embedding 4: mean=2.719, sd=4.202, n=54
#
#   [GRNN]
#   +wh:
#     embedding 0: mean=2.481, sd=6.139, n=54
#     embedding 1: mean=3.276, sd=6.250, n=54
#     embedding 2: mean=3.606, sd=6.110, n=54
#     embedding 3: mean=4.018, sd=5.907, n=54
#     embedding 4: mean=4.018, sd=5.907, n=54
#   -wh:
#     embedding 0: mean=4.614, sd=5.855, n=54
#     embedding 1: mean=4.513, sd=5.992, n=54
#     embedding 2: mean=4.550, sd=5.895, n=54
#     embedding 3: mean=4.329, sd=5.748, n=54
#     embedding 4: mean=4.329, sd=5.748, n=54
#
#   [ngram]
#   +wh:
#     embedding 0: mean=3.598, sd=5.048, n=54
#     embedding 1: mean=3.598, sd=5.048, n=54
#     embedding 2: mean=3.598, sd=5.048, n=54
#     embedding 3: mean=3.598, sd=5.048, n=54
#     embedding 4: mean=3.598, sd=5.048, n=54
#   -wh:
#     embedding 0: mean=3.598, sd=5.048, n=54
#     embedding 1: mean=3.598, sd=5.048, n=54
#     embedding 2: mean=3.598, sd=5.048, n=54
#     embedding 3: mean=3.598, sd=5.048, n=54
#     embedding 4: mean=3.598, sd=5.048, n=54
