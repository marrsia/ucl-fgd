# %%
from utils.text_utils import *
from utils.data_analysis_utils import *

# %%
surprisal_df = pd.read_csv('../data/model_outputs/gpt2_pilot_object_gaps_stimuli_with_surprisals.csv')

get_region_token_ids(surprisal_df, "verb", 1, "gpt2")
# Out:
# ('impressed', (8, 9))

# %%
surprisal_df = pd.read_csv('../data/model_outputs/gpt2_pilot_object_gaps_stimuli_with_surprisals.csv')

get_region_token_ids(surprisal_df, "verb", 1, "grnn")
# Out:
# ('impressed', (6, 7))

# %%
configs = [
    {'sentence_group': 1, 'condition': 'gap_filler',       'levels_of_embedding': 0},
    {'sentence_group': 1, 'condition': 'gap_no_filler',    'levels_of_embedding': 0},
    {'sentence_group': 1, 'condition': 'no_gap_no_filler', 'levels_of_embedding': 0},
    {'sentence_group': 1, 'condition': 'no_gap_filler',    'levels_of_embedding': 0},
]

data_analysis_utils.plot_surprisal_lines('../data/model_outputs/gpt2_pilot_object_gaps_stimuli_with_surprisals.csv', configs)
# Out:
# ['main_clause', 'complementiser', 'subject', 'verb', 'object', 'continuation']
# sentence_group                                    1
# gap                                             yes
# filler                                          yes
# levels_of_embedding                               0
# condition                                gap_filler
# main_clause                      The assistant knew
# complementiser                                  who
# embedding_1                                     NaN
# embedding_2                                     NaN
# embedding_3                                     NaN
# subject                               the secretary
# verb                                      impressed
# object                                 the director
# continuation                        at the meeting.
# main_clause_surprisal                      4.729313
# main_clause_surprisal_mean                 9.695215
# complementiser_surprisal                   6.747474
# complementiser_surprisal_mean                   NaN
# embedding_1_surprisal                           NaN
# embedding_1_surprisal_mean                      NaN
# embedding_2_surprisal                           NaN
# embedding_2_surprisal_mean                      NaN
# embedding_3_surprisal                           NaN
# embedding_3_surprisal_mean                      NaN
# subject_surprisal                          3.798539
# subject_surprisal_mean                     3.798539
# verb_surprisal                            22.871823
# verb_surprisal_mean                             NaN
# object_surprisal                           6.622082
# object_surprisal_mean                      6.622082
# continuation_surprisal                     6.538787
# continuation_surprisal_mean                4.893178
# Name: 1, dtype: object
# [9.6952145, None, 3.798539, None, 6.622082, 4.893177666666666]
# ['main_clause', 'complementiser', 'subject', 'verb', 'object', 'continuation']
# sentence_group                                    1
# gap                                             yes
# filler                                           no
# levels_of_embedding                               0
# condition                             gap_no_filler
# main_clause                      The assistant knew
# complementiser                                  who
# embedding_1                                     NaN
# embedding_2                                     NaN
# embedding_3                                     NaN
# subject                               the secretary
# verb                                      impressed
# object                                          NaN
# continuation                        at the meeting.
# main_clause_surprisal                      4.729313
# main_clause_surprisal_mean                 9.695215
# complementiser_surprisal                   6.747474
# complementiser_surprisal_mean                   NaN
# embedding_1_surprisal                           NaN
# embedding_1_surprisal_mean                      NaN
# embedding_2_surprisal                           NaN
# embedding_2_surprisal_mean                      NaN
# embedding_3_surprisal                           NaN
# embedding_3_surprisal_mean                      NaN
# subject_surprisal                          3.798539
# subject_surprisal_mean                     3.798539
# verb_surprisal                            22.871824
# verb_surprisal_mean                             NaN
# object_surprisal                                NaN
# object_surprisal_mean                           NaN
# continuation_surprisal                       6.1039
# continuation_surprisal_mean                4.580278
# Name: 0, dtype: object
# [9.6952145, None, 3.798539, None, None, 4.580278]
# ['main_clause', 'complementiser', 'subject', 'verb', 'object', 'continuation']
# sentence_group                                    1
# gap                                              no
# filler                                           no
# levels_of_embedding                               0
# condition                          no_gap_no_filler
# main_clause                      The assistant knew
# complementiser                                 that
# embedding_1                                     NaN
# embedding_2                                     NaN
# embedding_3                                     NaN
# subject                               the secretary
# verb                                      impressed
# object                                          NaN
# continuation                        at the meeting.
# main_clause_surprisal                      4.729313
# main_clause_surprisal_mean                 9.695215
# complementiser_surprisal                   3.218776
# complementiser_surprisal_mean                   NaN
# embedding_1_surprisal                           NaN
# embedding_1_surprisal_mean                      NaN
# embedding_2_surprisal                           NaN
# embedding_2_surprisal_mean                      NaN
# embedding_3_surprisal                           NaN
# embedding_3_surprisal_mean                      NaN
# subject_surprisal                          3.439892
# subject_surprisal_mean                     3.439892
# verb_surprisal                            19.580878
# verb_surprisal_mean                             NaN
# object_surprisal                                NaN
# object_surprisal_mean                           NaN
# continuation_surprisal                     8.153907
# continuation_surprisal_mean                5.440843
# Name: 2, dtype: object
# [9.6952145, None, 3.439892, None, None, 5.4408433333333335]
# ['main_clause', 'complementiser', 'subject', 'verb', 'object', 'continuation']
# sentence_group                                    1
# gap                                              no
# filler                                          yes
# levels_of_embedding                               0
# condition                             no_gap_filler
# main_clause                      The assistant knew
# complementiser                                 that
# embedding_1                                     NaN
# embedding_2                                     NaN
# embedding_3                                     NaN
# subject                               the secretary
# verb                                      impressed
# object                                 the director
# continuation                        at the meeting.
# main_clause_surprisal                      4.729313
# main_clause_surprisal_mean                 9.695215
# complementiser_surprisal                   3.218776
# complementiser_surprisal_mean                   NaN
# embedding_1_surprisal                           NaN
# embedding_1_surprisal_mean                      NaN
# embedding_2_surprisal                           NaN
# embedding_2_surprisal_mean                      NaN
# embedding_3_surprisal                           NaN
# embedding_3_surprisal_mean                      NaN
# subject_surprisal                          3.439892
# subject_surprisal_mean                     3.439892
# verb_surprisal                            19.580871
# verb_surprisal_mean                             NaN
# object_surprisal                           4.123414
# object_surprisal_mean                      4.123414
# continuation_surprisal                     6.859876
# continuation_surprisal_mean                4.900041
# Name: 3, dtype: object
# [9.6952145, None, 3.439892, None, 4.123414, 4.9000406666666665]

# %%
def group_sentences(df):
    """
    Groups sentences by sentence_group, levels_of_embedding, and condition.
    
    Returns:
        dict of {sentence_group: {levels_of_embedding: {condition: row as dict}}}
    """
    result = {}
    
    for _, row in df.iterrows():
        group = row["sentence_group"]
        level = row["levels_of_embedding"]
        condition = row["condition"]
        
        if group not in result:
            result[group] = {}
        
        if level not in result[group]:
            result[group][level] = {}
        
        result[group][level][condition] = row.to_dict()
    
    return result

# %%
df = pd.read_csv("../data/model_outputs/gpt2_pilot_object_gaps_output_stimuli_with_surprisals.csv")
grouped = group_sentences(df)

# access sentence group 1, embedding level 2
row = grouped[3][0]["no_gap_no_filler"]
print(row)
#for row in rows:
#    print(row["condition"], row["complementiser_surprisal"])
# Out:
# {'sentence_group': 3, 'gap': 'no', 'filler': 'no', 'levels_of_embedding': 0, 'condition': 'no_gap_no_filler', 'main_clause': 'I know', 'complementiser': 'that', 'embedding_1': nan, 'embedding_2': nan, 'embedding_3': nan, 'subject': 'the burglar', 'verb': 'stole', 'object': nan, 'continuation': 'the other night.', 'complementiser_surprisal': 2.74974, 'object_surprisal': nan, 'subject_surprisal': 4.424285, 'continuation_surprisal': 3.408626}

# %% [markdown]
# **Wilcox 2022, wh-effect**
#
# | | +wh | -wh |
# |---|---|---|
# | **+gap** | I know what the lion devoured _ at sunrise. | *I know that the lion devoured _ at sunrise. |
# | **-gap** | *I know what the lion devoured a gazelle at sunrise. | I know that the lion devoured a gazelle at sunrise. |
#
#
# ---
#
#
# **filler_offloading**
#
# | | +gap | -gap |
# |---|---|---|
# | **+wh** | I know what the lion devoured _ at sunrise. | *I know what the lion devoured a gazelle at sunrise. |
# | **-wh** | *I know that the lion devoured _ at sunrise. | I know that the lion devoured a gazelle at sunrise. |

# %%
surprisal_df = pd.read_csv('data/gpt2_surprisals.csv')

# wh-effect plot
plot_effect_bar_chart(
    surprisal_df,
    effect_fn=get_wh_effect,
    conditions=['gap', 'no_gap'],
    condition_labels=['+gap', '-gap'],
    title='Wh-Effect (GPT-2)',
    ylabel='Wh-Effect (surprisal difference)'
)

# filler offloading plot
plot_effect_bar_chart(
    surprisal_df,
    effect_fn=get_local_filler_offloading_effect,
    conditions=['+wh', '-wh'],
    condition_labels=['+wh', '-wh'],
    title='Local Filler Offloading Effect (GPT-2)',
    ylabel='Filler Offloading (surprisal difference)'
)

# %%
def compute_metrics(grouped):
    metrics = {}
    
    for group_id, levels in grouped.items():
        metrics[group_id] = {}
        
        for level, rows in levels.items():
            metrics[group_id][level] = {
              "wh_effect_no_filler": rows["gap_no_filler"]["continuation_surprisal"] - rows["no_gap_no_filler"]["continuation_surprisal"],
              "wh_effect_filler": rows["gap_filler"]["object_surprisal"] - rows["no_gap_filler"]["object_surprisal"],
              "filler_offloading_gap": rows["gap_no_filler"]["continuation_surprisal"] - rows["gap_filler"]["continuation_surprisal"],
              "filler_offloading_no_gap": rows["no_gap_no_filler"]["continuation_surprisal"] - rows["no_gap_filler"]["continuation_surprisal"]
              
            }
    
    return metrics

# %%
metrics = compute_metrics(grouped)

# %%
import matplotlib.pyplot as plt
import numpy as np

def plot_metrics(metrics):
    for group_id, levels in metrics.items():
        n_levels = len(levels)
        fig, axes = plt.subplots(1, n_levels, figsize=(5 * n_levels, 5), sharey=True)
        
        if n_levels == 1:
            axes = [axes]
        
        fig.suptitle(f"Sentence Group {group_id}", fontsize=14)
        
        for ax, (level, level_metrics) in zip(axes, sorted(levels.items())):
            labels = list(level_metrics.keys())
            values = list(level_metrics.values())
            colors = ["green" if "wh_effect" in l else "purple" for l in labels]
            short_labels = [l.replace("wh_effect_", "").replace("filler_offloading_", "") for l in labels]
            
            x = np.arange(len(labels))
            bars = ax.bar(x, values, color=colors)
            ax.set_title(f"Embedding level {level}")
            ax.set_xticks(x)
            ax.set_xticklabels(short_labels, rotation=30, ha="right", fontsize=8)
            ax.axhline(0, color="black", linewidth=0.8, linestyle="--")
        
        plt.tight_layout()
        plt.show()

# %% [markdown]
# # Metrics
# in all cases if model predicts gramaticality we would expect the left bar to be negative and the right to be positive.

# %% [markdown]
# ##  gpt2 metrics

# %%
df = pd.read_csv("../data/model_outputs/gpt2_pilot_object_gaps_output_stimuli_with_surprisals.csv")
grouped = group_sentences(df)
metrics = compute_metrics(grouped)
plot_metrics(metrics)

# %% [markdown]
# ## ngram metrics
# the only reason these are different is that in my case the preceding 5 words maybe different (comparing between filled gap and not-filled gap conditions), this isn't especially relevant

# %%
df = pd.read_csv("../data/model_outputs/ngram_pilot_object_gaps_output_stimuli_with_surprisals.csv")
grouped = group_sentences(df)
metrics = compute_metrics(grouped)
plot_metrics(metrics)

# %% [markdown]
# ## grnn metrics

# %%
df = pd.read_csv("../data/model_outputs/grnn_pilot_object_gaps_output_stimuli_with_surprisals.csv")
grouped = group_sentences(df)
metrics = compute_metrics(grouped)
plot_metrics(metrics)
