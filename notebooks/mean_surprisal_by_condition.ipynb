# %%
import sys
sys.path.insert(0, '..')

import pandas as pd
from utils import data_analysis_utils as data

# %%
# Set the path to your surprisals CSV here
gpt2_object_csv_path = "../data/model_outputs/gpt2_wilcox2022_embed4_object_gap_stimuli_with_surprisals.csv"
gpt2_subject_csv_path = "../data/model_outputs/gpt2_wilcox2022_embed4_subject_gap_stimuli_with_surprisals.csv"

grnn_object_csv_path = "../data/model_outputs/grnn_wilcox2022_embed4_object_gap_stimuli_with_surprisals.csv"
grnn_subject_csv_path = "../data/model_outputs/grnn_wilcox2022_embed4_subject_gap_stimuli_with_surprisals.csv"

ngram_object_csv_path = "../data/model_outputs/ngram_wilcox2022_embed4_object_gap_stimuli_with_surprisals.csv"
ngram_subject_csv_path = "../data/model_outputs/ngram_wilcox2022_embed4_subject_gap_stimuli_with_surprisals.csv"

# %% [markdown]
# ### GPT 2

# %%
surprisal_df_object = pd.read_csv(gpt2_object_csv_path)
surprisal_df_subject = pd.read_csv(gpt2_subject_csv_path)
surprisal_df = pd.concat([surprisal_df_object, surprisal_df_subject], axis = 0)
data.plot_mean_surprisal_by_condition(
    surprisal_df,
    title='Mean Local (range mean) Surprisal by Condition and Embedding Level (GPT-2)',
    conditions=['+wh_gap', '+wh_no_gap', '-wh_gap', '-wh_no_gap'],
    condition_labels=['+wh gap', '+wh no-gap', '-wh gap', '-wh no-gap'],
    surprisal_type="local_surprisal_mean"
)
# Out:
# === MEANS & SDs (Mean Local (range mean) Surprisal by Condition and Embedding Level (GPT-2)) ===
#
#   +wh gap:
#     embedding 0: mean=9.963, sd=5.407, n=108
#     embedding 1: mean=11.216, sd=6.224, n=108
#     embedding 2: mean=11.814, sd=6.517, n=108
#     embedding 3: mean=12.218, sd=6.899, n=108
#     embedding 4: mean=12.557, sd=7.215, n=108
#
#   +wh no-gap:
#     embedding 0: mean=8.179, sd=2.112, n=108
#     embedding 1: mean=8.238, sd=2.063, n=108
#     embedding 2: mean=7.853, sd=2.178, n=108
#     embedding 3: mean=7.506, sd=2.125, n=108
#     embedding 4: mean=7.215, sd=2.201, n=108
#
#   -wh gap:
#     embedding 0: mean=12.924, sd=6.434, n=108
#     embedding 1: mean=13.474, sd=6.675, n=108
#     embedding 2: mean=13.590, sd=7.061, n=108
#     embedding 3: mean=13.124, sd=6.961, n=108
#     embedding 4: mean=12.960, sd=7.289, n=108
#
#   -wh no-gap:
#     embedding 0: mean=7.362, sd=2.001, n=108
#     embedding 1: mean=7.083, sd=1.980, n=108
# ...

# %%
surprisal_df = pd.read_csv(gpt2_object_csv_path)

data.plot_surprisal_type_difference_by_condition(
    surprisal_df,
    title='Diff between local-first-token and local-region-mean Surprisal by Condition and Embedding Level (GPT-2, Subject Gap)',
    conditions=['+wh_gap', '+wh_no_gap', '-wh_gap', '-wh_no_gap'],
    condition_labels=['+wh gap', '+wh no-gap', '-wh gap', '-wh no-gap'],
    surprisal_type_1="local",
    surprisal_type_2="local_mean"
)
## for +gap local-first-token > local-mean, for -gap local-first-token < local-mean
## continuation in particular (no gap condition) regions tend to be pretty large: later words affect surprisals more

# %%
surprisal_df = pd.read_csv(gpt2_subject_csv_path)

data.plot_mean_surprisal_by_condition(
    surprisal_df,
    title='Mean Local Surprisal  (region mean) by Condition and Embedding Level (GPT-2, Subject Gap)',
    conditions=['+wh_gap', '+wh_no_gap', '-wh_gap', '-wh_no_gap'],
    condition_labels=['+wh gap', '+wh no-gap', '-wh gap', '-wh no-gap'],
    gap_type="subject",
    surprisal_type="local_mean"
)

# %%
surprisal_df = pd.read_csv(gpt2_subject_csv_path)

data.plot_surprisal_type_difference_by_condition(
    surprisal_df,
    title='Diff between local-first-token and local-region-mean Surprisal by Condition and Embedding Level (GPT-2, Subject Gap)',
    conditions=['+wh_gap', '+wh_no_gap', '-wh_gap', '-wh_no_gap'],
    condition_labels=['+wh gap', '+wh no-gap', '-wh gap', '-wh no-gap'],
    gap_type="subject",
    surprisal_type_1="local",
    surprisal_type_2="local_mean"
)
## for +gap local-first-token > local-mean, for -gap local-first-token < local-mean
## continuation in particular (no gap condition) regions tend to be pretty large: later words affect surprisals more

# %%
surprisal_df = pd.read_csv(grnn_object_csv_path)

data.plot_mean_surprisal_by_condition(
    surprisal_df,
    title='Mean Local Surprisal  (region mean) by Condition and Embedding Level (GRNN, Object Gap)',
    conditions=['+wh_gap', '+wh_no_gap', '-wh_gap', '-wh_no_gap'],
    condition_labels=['+wh gap', '+wh no-gap', '-wh gap', '-wh no-gap'],
    gap_type="object",
    surprisal_type="local_mean"
)

# %%
surprisal_df = pd.read_csv(grnn_subject_csv_path)

data.plot_mean_surprisal_by_condition(
    surprisal_df,
    title='Mean Local Surprisal (region mean) by Condition and Embedding Level (GRNN, Subject Gap)',
    conditions=['+wh_gap', '+wh_no_gap', '-wh_gap', '-wh_no_gap'],
    condition_labels=['+wh gap', '+wh no-gap', '-wh gap', '-wh no-gap'],
    gap_type="subject",
    surprisal_type="local_mean"
)

# %%
surprisal_df = pd.read_csv(ngram_object_csv_path)

data.plot_mean_surprisal_by_condition(
    surprisal_df,
    title='Mean Local Surprisal (region mean) by Condition and Embedding Level (n-gram, Object Gap)',
    conditions=['+wh_gap', '+wh_no_gap', '-wh_gap', '-wh_no_gap'],
    condition_labels=['+wh gap', '+wh no-gap', '-wh gap', '-wh no-gap'],
    gap_type="object",
    surprisal_type="local_mean"
)

# %%
surprisal_df = pd.read_csv(ngram_subject_csv_path)

data.plot_mean_surprisal_by_condition(
    surprisal_df,
    title='Mean Local Surprisal (region mean) by Condition and Embedding Level (n-gram, Subject Gap)',
    conditions=['+wh_gap', '+wh_no_gap', '-wh_gap', '-wh_no_gap'],
    condition_labels=['+wh gap', '+wh no-gap', '-wh gap', '-wh no-gap'],
    gap_type="subject",
    surprisal_type="local_mean"
)
