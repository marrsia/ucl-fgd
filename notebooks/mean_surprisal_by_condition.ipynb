# %%
import sys
sys.path.insert(0, '..')

import pandas as pd
from utils import data_analysis_utils as data

# %%
# Set the path to your surprisals CSV here
gpt2_object_csv_path = "../data/model_outputs/gpt2_wilcox2022_embed4_object_gap_stimuli_with_surprisals.csv"
gpt2_subject_csv_path = "../data/model_outputs/gpt2_wilcox2022_embed4_subject_gap_stimuli_with_surprisals.csv"

grnn_object_csv_path = "../data/model_outputs/grnn_wilcox2022_embed4_object_gap_stimuli_with_surprisals.csv"
grnn_subject_csv_path = "../data/model_outputs/grnn_wilcox2022_embed4_subject_gap_stimuli_with_surprisals.csv"

ngram_object_csv_path = "../data/model_outputs/ngram_wilcox2022_embed4_object_gap_stimuli_with_surprisals.csv"
ngram_subject_csv_path = "../data/model_outputs/ngram_wilcox2022_embed4_subject_gap_stimuli_with_surprisals.csv"

# %%
surprisal_df = pd.read_csv(gpt2_object_csv_path)

data.plot_mean_surprisal_by_condition(
    surprisal_df,
    title='Mean Local Surprisal by Condition and Embedding Level (GPT-2, Object Gap)',
    conditions=['+wh_gap', '+wh_no_gap', '-wh_gap', '-wh_no_gap'],
    condition_labels=['+wh gap', '+wh no-gap', '-wh gap', '-wh no-gap'],
    gap_type="object"
)
# Out:
# === MEANS & SDs (Mean Local Surprisal by Condition and Embedding Level (GPT-2, Object Gap)) ===
#
#   +wh gap:
#     embedding 0: mean=5.882, sd=2.740, n=54
#     embedding 1: mean=6.326, sd=3.051, n=54
#     embedding 2: mean=7.117, sd=3.295, n=54
#     embedding 3: mean=7.512, sd=3.517, n=54
#     embedding 4: mean=7.512, sd=3.517, n=54
#
#   +wh no-gap:
#     embedding 0: mean=6.817, sd=2.102, n=54
#     embedding 1: mean=6.426, sd=2.113, n=54
#     embedding 2: mean=5.597, sd=2.132, n=54
#     embedding 3: mean=5.084, sd=1.801, n=54
#     embedding 4: mean=5.084, sd=1.801, n=54
#
#   -wh gap:
#     embedding 0: mean=9.253, sd=3.408, n=54
#     embedding 1: mean=10.058, sd=3.542, n=54
#     embedding 2: mean=9.917, sd=3.738, n=54
#     embedding 3: mean=9.241, sd=3.731, n=54
#     embedding 4: mean=9.241, sd=3.731, n=54
#
#   -wh no-gap:
#     embedding 0: mean=4.064, sd=1.688, n=54
#     embedding 1: mean=4.013, sd=1.571, n=54
#     embedding 2: mean=4.007, sd=1.555, n=54
#     embedding 3: mean=4.088, sd=1.739, n=54
#     embedding 4: mean=4.088, sd=1.739, n=54

# %%
surprisal_df = pd.read_csv(gpt2_subject_csv_path)

data.plot_mean_surprisal_by_condition(
    surprisal_df,
    title='Mean Surprisal by Condition and Embedding Level (GPT-2, Subject Gap)',
    conditions=['+wh_gap', '+wh_no_gap', '-wh_gap', '-wh_no_gap'],
    condition_labels=['+wh gap', '+wh no-gap', '-wh gap', '-wh no-gap'],
    gap_type="subject"
)
# Out:
# === MEANS & SDs (Mean Surprisal by Condition and Embedding Level (GPT-2, Subject Gap)) ===
#
#   +wh gap:
#     embedding 0: mean=14.847, sd=3.447, n=54
#     embedding 1: mean=17.183, sd=2.997, n=54
#     embedding 2: mean=18.054, sd=3.110, n=54
#     embedding 3: mean=18.661, sd=3.656, n=54
#     embedding 4: mean=18.661, sd=3.656, n=54
#
#   +wh no-gap:
#     embedding 0: mean=4.877, sd=0.998, n=54
#     embedding 1: mean=6.408, sd=1.401, n=54
#     embedding 2: mean=5.758, sd=1.427, n=54
#     embedding 3: mean=5.373, sd=1.563, n=54
#     embedding 4: mean=5.373, sd=1.563, n=54
#
#   -wh gap:
#     embedding 0: mean=19.312, sd=2.245, n=54
#     embedding 1: mean=20.129, sd=2.071, n=54
#     embedding 2: mean=20.485, sd=2.758, n=54
#     embedding 3: mean=19.779, sd=3.121, n=54
#     embedding 4: mean=19.779, sd=3.121, n=54
#
#   -wh no-gap:
#     embedding 0: mean=3.966, sd=1.396, n=54
#     embedding 1: mean=4.363, sd=1.399, n=54
#     embedding 2: mean=3.509, sd=1.414, n=54
#     embedding 3: mean=3.325, sd=1.434, n=54
#     embedding 4: mean=3.325, sd=1.434, n=54

# %%
surprisal_df = pd.read_csv(grnn_object_csv_path)

data.plot_mean_surprisal_by_condition(
    surprisal_df,
    title='Mean Local Surprisal by Condition and Embedding Level (GRNN, Object Gap)',
    conditions=['+wh_gap', '+wh_no_gap', '-wh_gap', '-wh_no_gap'],
    condition_labels=['+wh gap', '+wh no-gap', '-wh gap', '-wh no-gap'],
    gap_type="object"
)
# Out:
# === MEANS & SDs (Mean Local Surprisal by Condition and Embedding Level (GRNN, Object Gap)) ===
#
#   +wh gap:
#     embedding 0: mean=7.940, sd=4.703, n=54
#     embedding 1: mean=8.878, sd=5.199, n=54
#     embedding 2: mean=9.050, sd=5.297, n=54
#     embedding 3: mean=9.654, sd=5.298, n=54
#     embedding 4: mean=9.654, sd=5.298, n=54
#
#   +wh no-gap:
#     embedding 0: mean=5.453, sd=2.158, n=54
#     embedding 1: mean=5.243, sd=2.142, n=54
#     embedding 2: mean=5.141, sd=2.237, n=54
#     embedding 3: mean=4.905, sd=2.508, n=54
#     embedding 4: mean=4.905, sd=2.508, n=54
#
#   -wh gap:
#     embedding 0: mean=10.573, sd=4.661, n=54
#     embedding 1: mean=10.599, sd=4.773, n=54
#     embedding 2: mean=10.511, sd=4.978, n=54
#     embedding 3: mean=10.557, sd=5.002, n=54
#     embedding 4: mean=10.557, sd=5.002, n=54
#
#   -wh no-gap:
#     embedding 0: mean=3.489, sd=1.775, n=54
#     embedding 1: mean=3.676, sd=1.633, n=54
#     embedding 2: mean=3.826, sd=1.738, n=54
#     embedding 3: mean=3.934, sd=1.837, n=54
#     embedding 4: mean=3.934, sd=1.837, n=54

# %%
surprisal_df = pd.read_csv(grnn_subject_csv_path)

data.plot_mean_surprisal_by_condition(
    surprisal_df,
    title='Mean Local Surprisal by Condition and Embedding Level (GRNN, Subject Gap)',
    conditions=['+wh_gap', '+wh_no_gap', '-wh_gap', '-wh_no_gap'],
    condition_labels=['+wh gap', '+wh no-gap', '-wh gap', '-wh no-gap'],
    gap_type="subject"
)
# Out:
# === MEANS & SDs (Mean Local Surprisal by Condition and Embedding Level (GRNN, Subject Gap)) ===
#
#   +wh gap:
#     embedding 0: mean=14.585, sd=3.765, n=54
#     embedding 1: mean=18.326, sd=2.966, n=54
#     embedding 2: mean=18.729, sd=2.910, n=54
#     embedding 3: mean=19.393, sd=3.027, n=54
#     embedding 4: mean=19.393, sd=3.027, n=54
#
#   +wh no-gap:
#     embedding 0: mean=5.542, sd=1.272, n=54
#     embedding 1: mean=5.353, sd=1.139, n=54
#     embedding 2: mean=5.315, sd=1.766, n=54
#     embedding 3: mean=4.493, sd=2.059, n=54
#     embedding 4: mean=4.493, sd=2.059, n=54
#
#   -wh gap:
#     embedding 0: mean=20.212, sd=3.018, n=54
#     embedding 1: mean=20.052, sd=2.522, n=54
#     embedding 2: mean=19.780, sd=2.635, n=54
#     embedding 3: mean=20.041, sd=2.921, n=54
#     embedding 4: mean=20.041, sd=2.921, n=54
#
#   -wh no-gap:
#     embedding 0: mean=2.312, sd=1.002, n=54
#     embedding 1: mean=3.763, sd=1.317, n=54
#     embedding 2: mean=3.947, sd=1.811, n=54
#     embedding 3: mean=3.602, sd=1.694, n=54
#     embedding 4: mean=3.602, sd=1.694, n=54

# %%
surprisal_df = pd.read_csv(ngram_object_csv_path)

data.plot_mean_surprisal_by_condition(
    surprisal_df,
    title='Mean Local Surprisal by Condition and Embedding Level (n-gram, Object Gap)',
    conditions=['+wh_gap', '+wh_no_gap', '-wh_gap', '-wh_no_gap'],
    condition_labels=['+wh gap', '+wh no-gap', '-wh gap', '-wh no-gap'],
    gap_type="object"
)
# Out:
# === MEANS & SDs (Mean Local Surprisal by Condition and Embedding Level (n-gram, Object Gap)) ===
#
#   +wh gap:
#     embedding 0: mean=8.879, sd=3.931, n=54
#     embedding 1: mean=8.879, sd=3.931, n=54
#     embedding 2: mean=8.879, sd=3.931, n=54
#     embedding 3: mean=8.879, sd=3.931, n=54
#     embedding 4: mean=8.879, sd=3.931, n=54
#
#   +wh no-gap:
#     embedding 0: mean=4.754, sd=1.574, n=54
#     embedding 1: mean=4.754, sd=1.574, n=54
#     embedding 2: mean=4.754, sd=1.574, n=54
#     embedding 3: mean=4.754, sd=1.574, n=54
#     embedding 4: mean=4.754, sd=1.574, n=54
#
#   -wh gap:
#     embedding 0: mean=8.879, sd=3.931, n=54
#     embedding 1: mean=8.879, sd=3.931, n=54
#     embedding 2: mean=8.879, sd=3.931, n=54
#     embedding 3: mean=8.879, sd=3.931, n=54
#     embedding 4: mean=8.879, sd=3.931, n=54
#
#   -wh no-gap:
#     embedding 0: mean=4.754, sd=1.574, n=54
#     embedding 1: mean=4.754, sd=1.574, n=54
#     embedding 2: mean=4.754, sd=1.574, n=54
#     embedding 3: mean=4.754, sd=1.574, n=54
#     embedding 4: mean=4.754, sd=1.574, n=54

# %%
surprisal_df = pd.read_csv(ngram_subject_csv_path)

data.plot_mean_surprisal_by_condition(
    surprisal_df,
    title='Mean Local Surprisal by Condition and Embedding Level (n-gram, Subject Gap)',
    conditions=['+wh_gap', '+wh_no_gap', '-wh_gap', '-wh_no_gap'],
    condition_labels=['+wh gap', '+wh no-gap', '-wh gap', '-wh no-gap'],
    gap_type="subject"
)
# Out:
# === MEANS & SDs (Mean Local Surprisal by Condition and Embedding Level (n-gram, Subject Gap)) ===
#
#   +wh gap:
#     embedding 0: mean=13.342, sd=3.359, n=54
#     embedding 1: mean=16.460, sd=2.217, n=54
#     embedding 2: mean=16.683, sd=2.277, n=54
#     embedding 3: mean=16.404, sd=2.146, n=54
#     embedding 4: mean=16.404, sd=2.146, n=54
#
#   +wh no-gap:
#     embedding 0: mean=6.547, sd=2.466, n=54
#     embedding 1: mean=4.658, sd=1.683, n=54
#     embedding 2: mean=4.603, sd=1.794, n=54
#     embedding 3: mean=4.760, sd=1.813, n=54
#     embedding 4: mean=4.760, sd=1.813, n=54
#
#   -wh gap:
#     embedding 0: mean=16.091, sd=2.731, n=54
#     embedding 1: mean=16.460, sd=2.217, n=54
#     embedding 2: mean=16.683, sd=2.277, n=54
#     embedding 3: mean=16.404, sd=2.146, n=54
#     embedding 4: mean=16.404, sd=2.146, n=54
#
#   -wh no-gap:
#     embedding 0: mean=3.533, sd=1.024, n=54
#     embedding 1: mean=4.658, sd=1.683, n=54
#     embedding 2: mean=4.603, sd=1.794, n=54
#     embedding 3: mean=4.760, sd=1.813, n=54
#     embedding 4: mean=4.760, sd=1.813, n=54
